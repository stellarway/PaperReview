# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.parse import urlparse

for i in range(1,27):
    url = 'http://www.bok.or.kr/portal/bbs/B0000245/list.do?'
    params = {
        'menuNo': 200761,
        'pageIndex': i,
        'searchWrd': '통화',
        'searchCnd':2
    }
    down_url = 'http://www.bok.or.kr/portal/cmmn/file/fileDown.do?'
    resp = requests.get(url, params = params)
    html = resp.text
    soup = bs(html, 'html.parser')

    # print (soup.find_all(class_ = 'titlesub'))
    li = soup.find(class_='bdLine type2').find_all('li')
    for row in li:
        try:
            r = row.find(class_ = 'row')
            title = row.find(class_= 'titlesub').text
            print(title)
            urlp = urlparse(r.find(class_ = 'fileGoupBox').ul.li.findNext('li').a['href'])
            downloadURLResource(down_url + urlp.query,title)
        except:
            pass
# Out:
# 금융통화위원회 의사록(2019년도 제10차)(2019.5.31.)
# 금융통화위원회 의사록(2019년도 제9차)(2019.5.9)
# 금융통화위원회 의사록(2019년도 제7차)(2019.4.18.)
# 금융통화위원회 의사록(2019년도 제4차)(2019.2.28.)
# 금융통화위원회 의사록(2019년도 제3차)(2019.2.14.)
# 금융통화위원회 의사록(2019년도 제2차)(2019.1.24.)
# 금융통화위원회 의사록(2018년도 제25차)(2018.12.26.)
# 금융통화위원회 의사록(2018년도 제22차)(2018.11.30.)
# 금융통화위원회 의사록(2018년도 제21차)(2018.11.8.)
# 금융통화위원회 의사록(2018년도 제19차)(2018.10.18.)
# 금융통화위원회 의사록(2018년도 제16차)(2018.8.31.)
# 금융통화위원회 의사록(2018년도 제14차)(2018.7.26.)
# 금융통화위원회 의사록(2018년도 제13차)(2018.7.12.)
# 금융통화위원회 의사록(2018년도 제10차)(2018.5.24.)
# 금융통화위원회 의사록(2018년도 제8차)(2018.4.26.)
# 금융통화위원회 의사록(2018년도 제7차)(2018.4.12.)
# 금융통화위원회 의사록(2018년도 제4차)(2018.2.27.)
# 금융통화위원회 의사록(2018년도 제3차)(2018.2.8.)
# 금융통화위원회 의사록(2018년도 제1차)(2018.1.18.)
# 금융통화위원회 의사록(2017년도 제25차)(2017.12.28.)
# 금융통화위원회 의사록(2017년도 제22차)(2017.11.30.)
# 금융통화위원회 의사록(2017년도 제21차)(2017.11.9.)
# 금융통화위원회 의사록(2017년도 제16차)(2017.8.31.)
# 금융통화위원회 의사록(2017년도 제13차)(2017.7.13.)
# 금융통화위원회 의사록(2017년도 제10차)(2017.5.25.)
# 금융통화위원회 의사록(2017년도 제8차)(2017.4.27.)
# 금융통화위원회 의사록(2017년도 제7차)(2017.4.13.)
# 금융통화위원회 의사록(2017년도 제4차)(2017.2.23.)
# 금융통화위원회 의사록(2017년도 제1차)(2017.1.13.)
# 금융통화위원회 의사록(2016년도 제26차)(2016.12.29.)
# 금융통화위원회 의사록(2016년도 제24차)(2016.12.15.)
# 금융통화위원회 의사록(2016년도 제22차)(2016.11.11.)
# 금융통화위원회 의사록(2016년도 제21차)(2016.10.27.)
# 금융통화위원회 의사록(2016년도 제20차)(2016.10.13.)
# 금융통화위원회 의사록(2016년도 제18차)(2016.9.9.)
# 금융통화위원회 의사록(2016년도 제16차)(2016.8.11.)
# 금융통화위원회 의사록(2016년도 제14차)(2016.7.14.)
# 금융통화위원회 의사록(2016년도 제11차)(2016.6.9.)
# 금융통화위원회 의사록(2016년도 제9차)(2016.5.13.)
# 금융통화위원회 의사록(2016년도 제7차)(2016.4.19.)
# 금융통화위원회 의사록(2016년도 제5차)(2016.3.10.)
# 금융통화위원회 의사록(2016년도 제3차)(2016.2.16)
# 금융통화위원회 의사록(2016년도 제1차)(2016.1.14.)
# 금융통화위원회 의사록(2015년도 제25차)(2015.12.24.)
# 금융통화위원회 의사록(2015년도 제23차)(2015.12.10.)
# 금융통화위원회 의사록(2015년도 제21차)(2015.11.12.)
# 금융통화위원회 의사록(2015년도 제20차)(2015.10.29.)
# 금융통화위원회 의사록(2015년도 제19차)(2015.10.15.)
# 금융통화위원회 의사록(2015년도 제17차)(2015.9.11.)
# 금융통화위원회 의사록(2015년도 제15차)(2015.8.13.)
# 금융통화위원회 의사록(2015년도 제13차)(2015.7.9.)
# 금융통화위원회 의사록(2015년도 제11차)(2015.6.11.)
# 금융통화위원회 의사록(2015년도 제9차)(2015.5.15.)
# 금융통화위원회 의사록(2015년도 제8차)(2015.4.23.)
# 금융통화위원회 의사록(2015년도 제7차)(2015.4.9.)
# 금융통화위원회 의사록(2015년도 제5차)(2015.3.12.)
# 금융통화위원회 의사록(2015년도 제3차)(2015.2.17.)
# 금융통화위원회 의사록(2015년도 제1차)(2015.1.15.)
# 금융통화위원회 의사록(2014년도 제24차)(2014.12.24.)
# 금융통화위원회 의사록(2014년도 제23차)(2014.12.11.)
# 금융통화위원회 의사록(2014년도 제21차)(2014.11.13.)
# 금융통화위원회 의사록(2014년도 제19차)(2014.10.15.)
# 금융통화위원회 의사록(2014년도 제18차)(2014.9.25.)
# 금융통화위원회 의사록(2014년도 제17차)(2014.9.12.)
# 금융통화위원회 의사록(2014년도 제15차)(2014.8.14.)
# 금융통화위원회 의사록(2014년도 제13차)(2014.7.10.)
# 금융통화위원회 의사록(2014년도 제11차)(2014.6.12.)
# 금융통화위원회 의사록(2014년도 제9차)(2014.5.9.)
# 금융통화위원회 의사록(2014년도 제7차)(2014.4.10.)
# 금융통화위원회 의사록(2014년도 제6차)(2014.3.27.)
# 금융통화위원회 의사록(2014년도 제5차)(2014.3.13.)
# 금융통화위원회 의사록(2014년도 제3차)(2014.2.13.)
# 금융통화위원회 의사록(2014년도 제1차)(2014.1.9)
# 금융통화위원회 의사록(2013년도 제24차)(2013.12.26.)
# 금융통화위원회 의사록(2013년도 제23차)(2013.12.12.)
# 금융통화위원회 의사록(2010년도 제22차)(2010.11.16)
# 금융통화위원회 의사록(2010년도 제20차)(2010.10.14)
# 금융통화위원회 의사록(2010년도 제19차)(2010.9.24)
# 금융통화위원회 의사록(2010년도 제18차)(2010.9.9)
# 금융통화위원회 의사록(2010년도 제17차)(2010.8.31)
# 금융통화위원회 의사록(2010년도 제16차)(2010.8.12)
# 금융통화위원회 의사록(2010년도 제14차)(2010.7.9)
# 금융통화위원회 의사록(2010년도 제12차)(2010.6.10)
# 금융통화위원회 의사록(2010년도 제10차)(2010.5.12)
# 금융통화위원회 의사록(2010년도 제8차)(2010.4.9)
# 금융통화위원회 의사록(2010년도 제7차)(2010.3.25)
# 금융통화위원회 의사록(2010년도 제6차)(2010.3.11)
# 금융통화위원회 의사록(2010년도 제4차)(2010.2.11)
# 금융통화위원회 의사록(2010년도 제1차)(2010.1.7)
# 금융통화위원회 의사록(2010년도 제2차)(2010.1.8)
# 금융통화위원회 의사록(2009년도 제26차)(2009.12.10)
# 금융통화위원회 의사록(2009년도 제24차)(2009.11.12)
# 금융통화위원회 의사록(2009년도 제22차)(2009.10.9)
# 금융통화위원회 의사록(2009년도 제21차)(2009.9.24)
# 금융통화위원회 의사록(2009년도 제20차)(2009.9.10)
# 금융통화위원회 의사록(2009년도 제18차)(2009.8.11)
# 금융통화위원회 의사록(2009년도 제16차)(2009.7.9)
# 금융통화위원회 의사록(2009년도 제14차)(2009.6.11)
# 금융통화위원회 의사록(2009년도 제12차)(2009.5.12)
# 금융통화위원회 의사록(2009년도 제10차)(2009.4.23)
# 금융통화위원회 의사록(2009년도 제9차)(2009.4.9)
# 금융통화위원회 의사록(2009년도 제8차)(2009.3.26)
# 금융통화위원회 의사록(2009년도 제7차)(2009.3.12)
# 금융통화위원회 의사록(2009년도 제4차)(2009.2.12)
# 금융통화위원회 의사록(2009년도 제2차)(2009.1.9)
# 금융통화위원회 의사록(2009년도 제1차)(2009.1.2)
# 금융통화위원회 의사록(2008년도 제26차)(2008.12.11)
# 금융통화위원회 의사록(2008년도 제23차)(2008.11.7)
# 금융통화위원회 의사록(2008년도 제22차)(2008.10.27)
# 금융통화위원회 의사록(2008년도 제20차)(2008.10.9)
# 금융통화위원회 의사록(2008년도 제19차)(2008.9.25)
# 금융통화위원회 의사록(2008년도 제18차)(2008.9.11)
# 금융통화위원회 의사록(2008년도 제16차)(2008.8.7)
# 금융통화위원회 의사록(2008년도 제14차)(2008.7.10)
# 금융통화위원회 의사록(2008년도 제12차)(2008.6.12)
# 금융통화위원회 의사록(2008년도 제10차)(2008.5.8)
# 금융통화위원회 의사록(2008년도 제8차)(2008.4.10)
# 금융통화위원회 의사록(2008년도 제7차)(2008.3.20)
# 금융통화위원회 의사록(2008년도 제6차)(2008.3.7)
# 금융통화위원회 의사록(2008년도 제4차)(2008.2.13)
# 금융통화위원회 의사록(2004년도 제23차)(2004.11.11)
# 금융통화위원회 의사록(2004년도 제21차)(2004.10.7)
# 금융통화위원회 의사록(2004년도 제19차)(2004.9.9)
# 금융통화위원회 의사록(2004년도 제17차)(2004.8.12)
# 금융통화위원회 의사록(2004년도 제18차)(2004.8.26)
# 금융통화위원회 의사록(2004년도 제15차)(2004.7.8)
# 금융통화위원회 의사록(2004년도 제12차)(2004.6.10)
# 금융통화위원회 의사록(2004년도 제10차)(2004.5.6)
# 금융통화위원회 의사록(2004년도 제8차)(2004.4.8)
# 금융통화위원회 의사록(2004년도 제6차)(2004.3.11)
# 금융통화위원회 의사록(2004년도 제7차)(2004.3.25)
# 금융통화위원회 의사록(2004년도 제3차)(2004.2.6)
# 금융통화위원회 의사록(2004년도 제5차)(2004.2.26)
# 금융통화위원회 의사록(2004년도 제1차)(2004.1.8)
# 금융통화위원회 의사록(2003년도 제25차)(2003.12.11)
# 금융통화위원회 의사록(2003년도 제26차)(2003.12.18)
# 금융통화위원회 의사록(2003년도 제22차)(2003.11.6)
# 금융통화위원회 의사록(2003년도 제20차)(2003.10.9)
# 금융통화위원회 의사록(2003년도 제18차)(2003.9.9)
# 금융통화위원회 의사록(2003년도 제16차)(2003.8.7)
# 금융통화위원회 의사록(2003년도 제14차)(2003.7.10)
# 금융통화위원회 의사록(2003년도 제12차)(2003.6.12)
# 금융통화위원회 의사록(2003년도 제10차)(2003.5.13)
# 금융통화위원회 의사록(2003년도 제8차)(2003.4.10)
# 금융통화위원회 의사록(2003년도 제5차)(2003.3.6)
# 금융통화위원회 의사록(2003년도 제6차)(2003.3.20)
# 금융통화위원회 의사록(2003년도 제3차)(2003.2.6)
# 금융통화위원회 의사록(2003년도 제1차)(2003.1.9)
# 금융통화위원회 의사록(2002년도 제29차)(2002.12.12)
# 금융통화위원회 의사록(2002년도 제26차)(2002.11.7)
# 금융통화위원회 의사록(2002년도 제24차)(2002.10.10)
# 금융통화위원회 의사록(2002년도 제22차)(2002.9.12)
# 금융통화위원회 의사록(2002년도 제20차)(2002.8.6)
# 금융통화위원회 의사록(2002년도 제17차)(2002.7.4)
# 금융통화위원회 의사록(2002년도 제15차)(2002.6.5)
# 금융통화위원회 의사록(2002년도 제13차)(2002.5.7)
# 금융통화위원회 의사록(2002년도 제10차)(2002.4.4)
# 금융통화위원회 의사록(2002년도 제7차)(2002.3.7)
# 금융통화위원회 의사록(2002년도 제8차)(2002.3.21)
# 금융통화위원회 의사록(2002년도 제4차)(2002.2.7)
# 금융통화위원회 의사록(2002년도 제2차)(2002.1.10)
# 금융통화위원회 의사록(2001년도 제34차)(2001.12.6)
# 금융통화위원회 의사록(2001년도 제28차)(2001.10.11)
# 금융통화위원회 의사록(2001년도 제24차)(2001.9.6)
# 금융통화위원회 의사록(2001년도 제21차)(2001.8.9)
# 금융통화위원회 의사록(2001년도 제18차)(2001.7.5)
# 금융통화위원회 의사록(2001년도 제16차)(2001.6.7)

# %%
# 해당 url의 파일을 저장
import cgi
import requests

SAVE_DIR = 'C:\\Users\\student\\Documents\\testing2'
def downloadURLResource(url,title):
    r = requests.get(url, stream=True)
    if r.status_code == 200:
        targetFileName = title + '.pdf'
        with open("{}/{}".format(SAVE_DIR, targetFileName), 'wb') as f:
            f.write(r.content)
#             for chunk in r.iter_content(chunk_size=1024):
#                 f.write(chunk)
        return targetFileName

# %%
# pdf to txt
from pdfminer.pdfinterp import PDFResourceManager, process_pdf
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from cStringIO import StringIO
def pdfparser(data):
    try:
        fp = open(data, 'rb')
        rsrcmgr = PDFResourceManager()
        retstr = io.StringIO()
        codec = 'utf-8'
        laparams = LAParams()
        device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
        # Create a PDF interpreter object.
        interpreter = PDFPageInterpreter(rsrcmgr, device)
        # Process each page contained in the document.

        for page in PDFPage.get_pages(fp):
            interpreter.process_page(page)
            data =  retstr.getvalue()
            text_path = os.path.join(REPORTS_DIR, i + '.txt')
            with open(text_path, 'w', encoding='utf-8') as f:
                f.write(data)

    except AttributeError:
        pass
    if __name__ == '__main__':
        for i in pdf_list:
            pdfparser(i)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-195-6cf7878ec901> in <module>
# ----> 1 from pdfminer.pdfinterp import PDFResourceManager, process_pdf
#       2 from pdfminer.converter import TextConverter
#       3 from pdfminer.layout import LAParams
#       4 from cStringIO import StringIO
#       5 def pdfparser(data):
#
# ModuleNotFoundError: No module named 'pdfminer'

# %%
from pdfminer.pdfinterp import PDFResourceManager, process_pdf
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from io import StringIO
from io import open
from urllib.request import urlopen

# 다음 코드는 라이브러리에서 PDF 파일을 읽을 시 사용하는 전형적인 코드 형태이므로, 필요할 때 활용하면 됨
def read_pdf_file(pdfFile):
    rsrcmgr = PDFResourceManager()
    retstr = StringIO()
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, laparams=laparams)

    process_pdf(rsrcmgr, device, pdfFile)
    device.close()

    content = retstr.getvalue()
    retstr.close()
    return content.replace('\n','')

# %%
import os
pdflist = os.listdir('C:\\Users\\student\\Documents\\Testing')
try:
    for pdf in pdflist:
    #     print('C:\\Users\\student\\Documents\\Testing\\'+pdf)
#         pdf_file = open('C:\\Users\\student\\Documents\\Testing\\'+pdf,'rb')
        pdf_file = open(r'C:\Users\student\Documents\Testing\금융통화위원회 의사록(2019년도 제10차)(2019.5.31.).pdf','rb')
        contents = read_pdf_file(pdf_file)
#         text_path = os.path.join(pdf.replace(".pdf",".txt"))
        with open('a.txt','wb') as f:
            f.write(contents)
        break
except:
    pass
    
#     text_path = os.path.join(REPORTS_DIR, i + '.txt')
#             with open(text_path, 'w', encoding='utf-8') as f:
#                 f.write(data)
# Out:
# WARNING:pdfminer.cmapdb:The code b'\x07' has an uneven length, trimming last byte.
# WARNING:pdfminer.cmapdb:The code b'\x07' has an uneven length, trimming last byte.

# %%
pdf_file = open(r'C:\Users\student\Documents\Testing\금융통화위원회 의사록(2004년도 제5차)(2004.2.26).pdf', "rb")
contents = read_pdf_file(pdf_file)
print(contents)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-d7c1e040229d> in <module>
#       1 pdf_file = open(r'C:\Users\student\Documents\Testing\금융통화위원회 의사록(2004년도 제5차)(2004.2.26).pdf', "rb")
# ----> 2 contents = read_pdf_file(pdf_file)
#       3 print(contents)
#
# <ipython-input-2-b3258b702474> in read_pdf_file(pdfFile)
#      13     device = TextConverter(rsrcmgr, retstr, laparams=laparams)
#      14
# ---> 15     process_pdf(rsrcmgr, device, pdfFile)
#      16     device.close()
#      17
#
# C:\ProgramData\Anaconda3\lib\site-packages\pdfminer\pdfinterp.py in process_pdf(rsrcmgr, device, fp, pagenos, maxpages, password, caching, check_extractable)
#     705     for (pageno,page) in enumerate(doc.get_pages()):
#     706         if pagenos and (pageno not in pagenos): continue
# --> 707         interpreter.process_page(page)
#     708         if maxpages and maxpages <= pageno+1: break
#
# C:\ProgramData\Anaconda3\lib\site-packages\pdfminer\pdfinterp.py in process_page(self, page)
#     640             ctm = (1,0,0,1, -x0,-y0)
#     641         self.device.begin_page(page, ctm)
# --> 642         self.render_contents(page.resources, page.contents, ctm=ctm)
#     643         self.device.end_page(page)
#     644
#
# C:\ProgramData\Anaconda3\lib\site-packages\pdfminer\pdfinterp.py in render_contents(self, resources, streams, ctm)
#     648     def render_contents(self, resources, streams, ctm=MATRIX_IDENTITY):
#     649         logger.debug('render_contents: resources=%r, streams=%r, ctm=%r', resources, streams, ctm)
# --> 650         self.init_resources(resources)
#     651         self.init_state(ctm)
#     652         self.execute(list_value(streams))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pdfminer\pdfinterp.py in init_resources(self, resources)
#     278                     spec = dict_value(spec)
#     279                     if spec:
# --> 280                         self.fontmap[fontid] = self.rsrcmgr.get_font(objid, spec)
#     281             elif k == 'ColorSpace':
#     282                 for (csid,spec) in dict_value(v).items():
#
# C:\ProgramData\Anaconda3\lib\site-packages\pdfminer\pdfinterp.py in get_font(self, objid, spec)
#     166                     if k in spec:
#     167                         subspec[k] = resolve1(spec[k])
# --> 168                 font = self.get_font(None, subspec)
#     169             else:
#     170                 handle_error(PDFFontError, 'Invalid Font spec: %r' % spec)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pdfminer\pdfinterp.py in get_font(self, objid, spec)
#     157             elif subtype in ('CIDFontType0', 'CIDFontType2'):
#     158                 # CID Font
# --> 159                 font = PDFCIDFont(self, spec)
#     160             elif subtype == 'Type0':
#     161                 # Type0 Font
#
# C:\ProgramData\Anaconda3\lib\site-packages\pdfminer\pdffont.py in __init__(self, rsrcmgr, spec)
#     609             strm = stream_value(spec['ToUnicode'])
#     610             self.unicode_map = FileUnicodeMap()
# --> 611             CMapParser(self.unicode_map, io.BytesIO(strm.get_data())).run()
#     612         elif self.cidcoding == 'Adobe-Identity':
#     613             if ttf:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pdfminer\cmapdb.py in run(self)
#     262     def run(self):
#     263         try:
# --> 264             self.nextobject()
#     265         except PSEOF:
#     266             pass
#
# C:\ProgramData\Anaconda3\lib\site-packages\pdfminer\psparser.py in nextobject(self)
#     278             else:
#     279                 logging.debug('do_keyword: pos=%r, token=%r, stack=%r', pos, token, self.curstack)
# --> 280                 self.do_keyword(pos, token)
#     281             if self.context:
#     282                 continue
#
# C:\ProgramData\Anaconda3\lib\site-packages\pdfminer\cmapdb.py in do_keyword(self, pos, token)
#     289             try:
#     290                 ((_,cmapname),) = self.pop(1)
# --> 291                 self.cmap.use_cmap(CMapDB.get_cmap(literal_name(cmapname)))
#     292             except PSSyntaxError:
#     293                 pass
#
# AttributeError: 'FileUnicodeMap' object has no attribute 'use_cmap'
