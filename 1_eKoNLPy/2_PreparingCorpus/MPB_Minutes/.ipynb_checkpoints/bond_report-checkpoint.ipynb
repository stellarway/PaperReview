# %%
pip install pdfminer3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
from PyPDF2 import PdfFileReader
import sys
from pdfminer3.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer3.pdfpage import PDFPage
from pdfminer3.converter import XMLConverter, HTMLConverter, TextConverter
from pdfminer3.layout import LAParams
import io
from urllib.request import urlopen

# %%
def content_to_txt(pdf_content, name):
    #file_res = requests.get(pdf_link)
    with open(name,'w', encoding='utf-8') as f:
        f.write(pdf_content)

# %%
def pdfparser(filename):

    fp = open(filename, 'rb')
    rsrcmgr = PDFResourceManager()
    retstr = io.StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    # Create a PDF interpreter object.
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    # Process each page contained in the document.

    for page in PDFPage.get_pages(fp):
        interpreter.process_page(page)
        data = retstr.getvalue()
    fp.close()

    return data.replace('\n','')

# %%
#1134번째에서 멈춤.

# %%
import os


os.listdir(r"C:\Users\student\Documents\Thesis\1_eKoNLPy\1_PreparingCorpus\MPB_Minutes\금융통화위원회 의사록/")
# Out:
# ['금융통화위원회 의사록(2004년도 제1차)(2004.1.8).pdf',
#  '금융통화위원회 의사록(2004년도 제23차)(2004.11.11).pdf',
#  '금융통화위원회 의사록(2004년도 제3차)(2004.2.6).pdf',
#  '금융통화위원회 의사록(2004년도 제5차)(2004.2.26).pdf',
#  '금융통화위원회 의사록(2004년도 제6차)(2004.3.11).pdf',
#  '금융통화위원회 의사록(2004년도 제7차)(2004.3.25).pdf',
#  '금융통화위원회 의사록(2004년도 제8차)(2004.4.8).pdf',
#  '금융통화위원회 의사록(2005년도 제12차)(2005.6.9).pdf',
#  '금융통화위원회 의사록(2005년도 제14차)(2005.7.7).pdf',
#  '금융통화위원회 의사록(2005년도 제17차)(2005.8.11).pdf',
#  '금융통화위원회 의사록(2005년도 제19차)(2005.9.8).pdf',
#  '금융통화위원회 의사록(2005년도 제20차)(2005.9.22).pdf',
#  '금융통화위원회 의사록(2005년도 제21차)(2005.10.11).pdf',
#  '금융통화위원회 의사록(2005년도 제24차)(2005.11.10).pdf',
#  '금융통화위원회 의사록(2005년도 제26차)(2005.12.8).pdf',
#  '금융통화위원회 의사록(2006년도 제10차)(2006.5.11).pdf',
#  '금융통화위원회 의사록(2006년도 제12차)(2006.6.8).pdf',
#  '금융통화위원회 의사록(2006년도 제14차)(2006.7.7).pdf',
#  '금융통화위원회 의사록(2006년도 제16차)(2006.8.10).pdf',
#  '금융통화위원회 의사록(2006년도 제19차)(2006.9.7).pdf',
#  '금융통화위원회 의사록(2006년도 제1차)(2006.1.5).pdf',
#  '금융통화위원회 의사록(2006년도 제20차)(2006.9.21).pdf',
# ...

# %%
#final_list = []
count_i=0
for txt_file_name in titleList:
    
          
    try:

        content_to_txt(pdfparser(txt_file_name), txt_file_name)
    except AttributeError:
        print('attribute error로 파일 변환 실패')
        pass
    except OSError:
        print('OSError로 파일 변환 실패')
        pass
    except:
        print('다른 에러로 파일 변환 실패')
        pass

    count_i+=1

    print(txt_file_name,', {}번째 파일 변환 완료'.format(count_i))
# Out:
# OSError로 파일 변환 실패
# 금융통화위원회 의사록(2004년도 제1차)(2004.1.8).pdf , 1번째 파일 변환 완료
# OSError로 파일 변환 실패
# 금융통화위원회 의사록(2004년도 제23차)(2004.11.11).pdf , 2번째 파일 변환 완료
# OSError로 파일 변환 실패
# 금융통화위원회 의사록(2004년도 제3차)(2004.2.6).pdf , 3번째 파일 변환 완료
# OSError로 파일 변환 실패
# 금융통화위원회 의사록(2004년도 제5차)(2004.2.26).pdf , 4번째 파일 변환 완료
# OSError로 파일 변환 실패
# 금융통화위원회 의사록(2004년도 제6차)(2004.3.11).pdf , 5번째 파일 변환 완료
# OSError로 파일 변환 실패
# 금융통화위원회 의사록(2004년도 제7차)(2004.3.25).pdf , 6번째 파일 변환 완료
# OSError로 파일 변환 실패
# 금융통화위원회 의사록(2004년도 제8차)(2004.4.8).pdf , 7번째 파일 변환 완료
# OSError로 파일 변환 실패
# 금융통화위원회 의사록(2005년도 제12차)(2005.6.9).pdf , 8번째 파일 변환 완료
# OSError로 파일 변환 실패
# 금융통화위원회 의사록(2005년도 제14차)(2005.7.7).pdf , 9번째 파일 변환 완료
# OSError로 파일 변환 실패
# 금융통화위원회 의사록(2005년도 제17차)(2005.8.11).pdf , 10번째 파일 변환 완료
# OSError로 파일 변환 실패
# 금융통화위원회 의사록(2005년도 제19차)(2005.9.8).pdf , 11번째 파일 변환 완료
# OSError로 파일 변환 실패
# 금융통화위원회 의사록(2005년도 제20차)(2005.9.22).pdf , 12번째 파일 변환 완료
# OSError로 파일 변환 실패
# 금융통화위원회 의사록(2005년도 제21차)(2005.10.11).pdf , 13번째 파일 변환 완료
# ...
