# %%
import pandas as pd
from ekonlpy.sentiment import MPCK
import re

# %%
doctorrock_label = pd.read_csv('doctorrock_label.csv',index_col = 0)
bondreport_label = pd.read_csv('bondreport_label.csv',index_col = 0)
news_ngrams_label = pd.read_csv('news_ngrams_withNone.csv',index_col = 0)
news_tokens_label = pd.read_csv('news_tokens_withNone.csv',index_col = 0)

# %%
bond_doctor = doctorrock_label.append(bondreport_label, ignore_index =  True).append(news_tokens_label, ignore_index =  True).append(news_ngrams_label, ignore_index =  True)
len(bond_doctor)
# Out:
# 464726

# %%
bond_doctor.head()
# Out:
#          date                                             tokens  \
# 0  2005-06-09  ['경제/NNG', '경제/NNG', '비해/VV', '더/MAG', '낫/VV',...
# 1  2005-06-09  ['환율/NNG', '장기/NNG', '각국/NNG', '기초/NNG', '경제/N...
# 2  2005-06-09  ['유로존/NNG', '경제/NNG', '성장/NNG', '실적/NNG', '예상/...
# 3  2005-06-09  ['금리/NNG', '수준/NNG', '유지/NNG', '되/XSV', '금리/NN...
# 4  2005-06-09  ['실물/NNG', '경제/NNG', '시차/NNG', '두/VV', '밀접/NNG...
#
#                                               ngrams label
# 0  ['엔달러/NNG;환율/NNG;상승/NNG', '기대/NNG;원화/NNG;절상/NN...   neg
# 1  ['원엔/NNG;환율/NNG;하락/NNG', '일시적/VAX;외부충격/NNG', '...   neg
# 2  ['유로존/NNG;경제/NNG;성장/NNG', '실적/NNG;예상/NNG;저조/NN...   neg
# 3  ['자본/NNG;유출/NNG;확대/NNG', '금리/NNG;상승/NNG', '원화/...   neg
# 4                                                 []   neg

# %%
len(bond_doctor['tokens'])
# Out:
# 464726

# %%
def stopPos(df):
    for idx in range(len(df['tokens'])):
        if df['tokens'][idx] == '[]':
            continue
        else:
            df['tokens'][idx] = re.sub(r'\'\S+\/(SC|SY|SF|SE|SS|SP|SO|SW|SSC\
                               |JKS|JKC|JKG|JKO|JKB|JKV|JKQ|JX|JC\
                               |EF|EC|ETN|ETM)\'\,?\s?','', df['tokens'][idx])
        if idx%1000==0:
            print(idx)
    return df

# %%
bond_doctor = stopPos(bond_doctor)
bond_doctor.head()
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# 123000
# 124000
# 125000
# 126000
# 127000
# 128000
# 129000
# 130000
# 131000
# 132000
# 133000
# 134000
# 135000
# 136000
# 137000
# 138000
# 139000
# 140000
# 141000
# 142000
# 143000
# 144000
# 145000
# 146000
# 147000
# 148000
# 149000
# 150000
# 151000
# 152000
# 153000
# 154000
# 155000
# 156000
# 157000
# 158000
# 159000
# 160000
# 162000
# 163000
# 164000
# 165000
# 166000
# 167000
# 168000
# 169000
# 170000
# 171000
# 172000
# 173000
# 174000
# 175000
# 176000
# 177000
# 178000
# 179000
# 180000
# 181000
# 182000
# 183000
# 184000
# 185000
# 186000
# 187000
# 188000
# 189000
# 190000
# 191000
# 192000
# 193000
# 194000
# 195000
# 196000
# 197000
# 198000
# 199000
# 200000
# 201000
# 202000
# 203000
# 204000
# 205000
# 206000
# 208000
# 209000
# 210000
# 211000
# 212000
# 213000
# 214000
# 215000
# 216000
# 217000
# 218000
# 219000
#          date                                             tokens  \
# 0  2005-06-09  ['경제/NNG', '경제/NNG', '비해/VV', '더/MAG', '낫/VV',...
# 1  2005-06-09  ['환율/NNG', '장기/NNG', '각국/NNG', '기초/NNG', '경제/N...
# 2  2005-06-09  ['유로존/NNG', '경제/NNG', '성장/NNG', '실적/NNG', '예상/...
# 3  2005-06-09  ['금리/NNG', '수준/NNG', '유지/NNG', '되/XSV', '금리/NN...
# 4  2005-06-09  ['실물/NNG', '경제/NNG', '시차/NNG', '두/VV', '밀접/NNG...
#
#                                               ngrams label
# 0  ['엔달러/NNG;환율/NNG;상승/NNG', '기대/NNG;원화/NNG;절상/NN...   neg
# 1  ['원엔/NNG;환율/NNG;하락/NNG', '일시적/VAX;외부충격/NNG', '...   neg
# 2  ['유로존/NNG;경제/NNG;성장/NNG', '실적/NNG;예상/NNG;저조/NN...   neg
# 3  ['자본/NNG;유출/NNG;확대/NNG', '금리/NNG;상승/NNG', '원화/...   neg
# 4                                                 []   neg

# %%
def selectFeat(df):
    allTokens=[]
    allNgrams=[]
    
    num=0
    for item in df['tokens']:
        li = eval(item)
        allTokens.extend(li)
        num+=1
        if num%1000==0:
            print('tokens {}번째까지 병합완료'.format(num))
    tokens15 = list(pd.Series(allTokens).value_counts()[pd.Series(allTokens).value_counts() >= 15].index)
    print('tokens에서 15회 이상 엔그램 추출완료')
    
    num=0
    for item in df['ngrams']:
        li = eval(item)
        allNgrams.extend(li)
        num+=1
        if num%1000==0:
            print('ngrams {}번째까지 병합완료'.format(num))
    ngrams15 = list(pd.Series(allNgrams).value_counts()[pd.Series(allNgrams).value_counts() >= 15].index)
    print('ngrams에서 15회 이상 엔그램 추출완료')

    return tokens15+ngrams15

# %%
ngrams_over15 = selectFeat(bond_doctor)
len(ngrams_over15)
# Out:
# tokens 1000번째까지 병합완료
# tokens 2000번째까지 병합완료
# tokens 3000번째까지 병합완료
# tokens 4000번째까지 병합완료
# tokens 5000번째까지 병합완료
# tokens 6000번째까지 병합완료
# tokens 7000번째까지 병합완료
# tokens 8000번째까지 병합완료
# tokens 9000번째까지 병합완료
# tokens 10000번째까지 병합완료
# tokens 11000번째까지 병합완료
# tokens 12000번째까지 병합완료
# tokens 13000번째까지 병합완료
# tokens 14000번째까지 병합완료
# tokens 15000번째까지 병합완료
# tokens 16000번째까지 병합완료
# tokens 17000번째까지 병합완료
# tokens 18000번째까지 병합완료
# tokens 19000번째까지 병합완료
# tokens 20000번째까지 병합완료
# tokens 21000번째까지 병합완료
# tokens 22000번째까지 병합완료
# tokens 23000번째까지 병합완료
# tokens 24000번째까지 병합완료
# tokens 25000번째까지 병합완료
# tokens 26000번째까지 병합완료
# tokens 27000번째까지 병합완료
# tokens 28000번째까지 병합완료
# tokens 29000번째까지 병합완료
# tokens 30000번째까지 병합완료
# tokens 31000번째까지 병합완료
# tokens 32000번째까지 병합완료
# tokens 33000번째까지 병합완료
# tokens 34000번째까지 병합완료
# tokens 35000번째까지 병합완료
# tokens 36000번째까지 병합완료
# tokens 37000번째까지 병합완료
# tokens 38000번째까지 병합완료
# tokens 39000번째까지 병합완료
# tokens 40000번째까지 병합완료
# tokens 41000번째까지 병합완료
# tokens 42000번째까지 병합완료
# tokens 43000번째까지 병합완료
# tokens 44000번째까지 병합완료
# tokens 45000번째까지 병합완료
# tokens 46000번째까지 병합완료
# tokens 47000번째까지 병합완료
# tokens 48000번째까지 병합완료
# tokens 49000번째까지 병합완료
# tokens 50000번째까지 병합완료
# tokens 51000번째까지 병합완료
# tokens 52000번째까지 병합완료
# tokens 53000번째까지 병합완료
# tokens 54000번째까지 병합완료
# tokens 55000번째까지 병합완료
# tokens 56000번째까지 병합완료
# tokens 57000번째까지 병합완료
# tokens 58000번째까지 병합완료
# tokens 59000번째까지 병합완료
# tokens 60000번째까지 병합완료
# tokens 61000번째까지 병합완료
# tokens 62000번째까지 병합완료
# tokens 63000번째까지 병합완료
# tokens 64000번째까지 병합완료
# tokens 65000번째까지 병합완료
# tokens 66000번째까지 병합완료
# tokens 67000번째까지 병합완료
# tokens 68000번째까지 병합완료
# tokens 69000번째까지 병합완료
# tokens 70000번째까지 병합완료
# tokens 71000번째까지 병합완료
# tokens 72000번째까지 병합완료
# tokens 73000번째까지 병합완료
# tokens 74000번째까지 병합완료
# tokens 75000번째까지 병합완료
# tokens 76000번째까지 병합완료
# tokens 77000번째까지 병합완료
# tokens 78000번째까지 병합완료
# tokens 79000번째까지 병합완료
# tokens 80000번째까지 병합완료
# tokens 81000번째까지 병합완료
# tokens 82000번째까지 병합완료
# tokens 83000번째까지 병합완료
# tokens 84000번째까지 병합완료
# tokens 85000번째까지 병합완료
# tokens 86000번째까지 병합완료
# tokens 87000번째까지 병합완료
# tokens 88000번째까지 병합완료
# tokens 89000번째까지 병합완료
# tokens 90000번째까지 병합완료
# tokens 91000번째까지 병합완료
# tokens 92000번째까지 병합완료
# tokens 93000번째까지 병합완료
# tokens 94000번째까지 병합완료
# tokens 95000번째까지 병합완료
# tokens 96000번째까지 병합완료
# tokens 97000번째까지 병합완료
# tokens 98000번째까지 병합완료
# tokens 99000번째까지 병합완료
# tokens 100000번째까지 병합완료
# tokens 101000번째까지 병합완료
# tokens 102000번째까지 병합완료
# tokens 103000번째까지 병합완료
# tokens 104000번째까지 병합완료
# tokens 105000번째까지 병합완료
# tokens 106000번째까지 병합완료
# tokens 107000번째까지 병합완료
# tokens 108000번째까지 병합완료
# tokens 109000번째까지 병합완료
# tokens 110000번째까지 병합완료
# tokens 111000번째까지 병합완료
# tokens 112000번째까지 병합완료
# tokens 113000번째까지 병합완료
# tokens 114000번째까지 병합완료
# tokens 115000번째까지 병합완료
# tokens 116000번째까지 병합완료
# tokens 117000번째까지 병합완료
# tokens 118000번째까지 병합완료
# tokens 119000번째까지 병합완료
# tokens 120000번째까지 병합완료
# tokens 121000번째까지 병합완료
# tokens 122000번째까지 병합완료
# tokens 123000번째까지 병합완료
# tokens 124000번째까지 병합완료
# tokens 125000번째까지 병합완료
# tokens 126000번째까지 병합완료
# tokens 127000번째까지 병합완료
# tokens 128000번째까지 병합완료
# tokens 129000번째까지 병합완료
# tokens 130000번째까지 병합완료
# tokens 131000번째까지 병합완료
# tokens 132000번째까지 병합완료
# tokens 133000번째까지 병합완료
# tokens 134000번째까지 병합완료
# tokens 135000번째까지 병합완료
# tokens 136000번째까지 병합완료
# tokens 137000번째까지 병합완료
# tokens 138000번째까지 병합완료
# tokens 139000번째까지 병합완료
# tokens 140000번째까지 병합완료
# tokens 141000번째까지 병합완료
# tokens 142000번째까지 병합완료
# tokens 143000번째까지 병합완료
# tokens 144000번째까지 병합완료
# tokens 145000번째까지 병합완료
# tokens 146000번째까지 병합완료
# tokens 147000번째까지 병합완료
# tokens 148000번째까지 병합완료
# tokens 149000번째까지 병합완료
# tokens 150000번째까지 병합완료
# tokens 151000번째까지 병합완료
# tokens 152000번째까지 병합완료
# tokens 153000번째까지 병합완료
# tokens 154000번째까지 병합완료
# tokens 155000번째까지 병합완료
# tokens 156000번째까지 병합완료
# tokens 157000번째까지 병합완료
# tokens 158000번째까지 병합완료
# tokens 159000번째까지 병합완료
# tokens 160000번째까지 병합완료
# tokens 161000번째까지 병합완료
# tokens 162000번째까지 병합완료
# tokens 163000번째까지 병합완료
# tokens 164000번째까지 병합완료
# tokens 165000번째까지 병합완료
# tokens 166000번째까지 병합완료
# tokens 167000번째까지 병합완료
# tokens 168000번째까지 병합완료
# tokens 169000번째까지 병합완료
# tokens 170000번째까지 병합완료
# tokens 171000번째까지 병합완료
# tokens 172000번째까지 병합완료
# tokens 173000번째까지 병합완료
# tokens 174000번째까지 병합완료
# tokens 175000번째까지 병합완료
# tokens 176000번째까지 병합완료
# tokens 177000번째까지 병합완료
# tokens 178000번째까지 병합완료
# tokens 179000번째까지 병합완료
# tokens 180000번째까지 병합완료
# tokens 181000번째까지 병합완료
# tokens 182000번째까지 병합완료
# tokens 183000번째까지 병합완료
# tokens 184000번째까지 병합완료
# tokens 185000번째까지 병합완료
# tokens 186000번째까지 병합완료
# tokens 187000번째까지 병합완료
# tokens 188000번째까지 병합완료
# tokens 189000번째까지 병합완료
# tokens 190000번째까지 병합완료
# tokens 191000번째까지 병합완료
# tokens 192000번째까지 병합완료
# tokens 193000번째까지 병합완료
# tokens 194000번째까지 병합완료
# tokens 195000번째까지 병합완료
# tokens 196000번째까지 병합완료
# tokens 197000번째까지 병합완료
# tokens 198000번째까지 병합완료
# tokens 199000번째까지 병합완료
# tokens 200000번째까지 병합완료
# tokens 201000번째까지 병합완료
# tokens 202000번째까지 병합완료
# tokens 203000번째까지 병합완료
# tokens 204000번째까지 병합완료
# tokens 205000번째까지 병합완료
# tokens 206000번째까지 병합완료
# tokens 207000번째까지 병합완료
# tokens 208000번째까지 병합완료
# tokens 209000번째까지 병합완료
# tokens 210000번째까지 병합완료
# tokens 211000번째까지 병합완료
# tokens 212000번째까지 병합완료
# tokens 213000번째까지 병합완료
# tokens 214000번째까지 병합완료
# tokens 215000번째까지 병합완료
# tokens 216000번째까지 병합완료
# tokens 217000번째까지 병합완료
# tokens 218000번째까지 병합완료
# tokens 219000번째까지 병합완료
# tokens 220000번째까지 병합완료
# tokens 221000번째까지 병합완료
# tokens 222000번째까지 병합완료
# tokens 223000번째까지 병합완료
# tokens 224000번째까지 병합완료
# tokens 225000번째까지 병합완료
# tokens 226000번째까지 병합완료
# tokens 227000번째까지 병합완료
# tokens 228000번째까지 병합완료
# tokens 229000번째까지 병합완료
# tokens 230000번째까지 병합완료
# tokens 231000번째까지 병합완료
# tokens 232000번째까지 병합완료
# tokens 233000번째까지 병합완료
# tokens 234000번째까지 병합완료
# tokens 235000번째까지 병합완료
# tokens 236000번째까지 병합완료
# tokens 237000번째까지 병합완료
# tokens 238000번째까지 병합완료
# tokens 239000번째까지 병합완료
# tokens 240000번째까지 병합완료
# tokens 241000번째까지 병합완료
# tokens 242000번째까지 병합완료
# tokens 243000번째까지 병합완료
# tokens 244000번째까지 병합완료
# tokens 245000번째까지 병합완료
# tokens 246000번째까지 병합완료
# tokens 247000번째까지 병합완료
# tokens 248000번째까지 병합완료
# tokens 249000번째까지 병합완료
# tokens 250000번째까지 병합완료
# tokens 251000번째까지 병합완료
# tokens 252000번째까지 병합완료
# tokens 253000번째까지 병합완료
# tokens 254000번째까지 병합완료
# tokens 255000번째까지 병합완료
# tokens 256000번째까지 병합완료
# tokens 257000번째까지 병합완료
# tokens 258000번째까지 병합완료
# tokens 259000번째까지 병합완료
# tokens 260000번째까지 병합완료
# tokens 261000번째까지 병합완료
# tokens 262000번째까지 병합완료
# tokens 263000번째까지 병합완료
# tokens 264000번째까지 병합완료
# tokens 265000번째까지 병합완료
# tokens 266000번째까지 병합완료
# tokens 267000번째까지 병합완료
# tokens 268000번째까지 병합완료
# tokens 269000번째까지 병합완료
# tokens 270000번째까지 병합완료
# tokens 271000번째까지 병합완료
# tokens 272000번째까지 병합완료
# tokens 273000번째까지 병합완료
# tokens 274000번째까지 병합완료
# tokens 275000번째까지 병합완료
# tokens 276000번째까지 병합완료
# tokens 277000번째까지 병합완료
# tokens 278000번째까지 병합완료
# tokens 279000번째까지 병합완료
# tokens 280000번째까지 병합완료
# tokens 281000번째까지 병합완료
# tokens 282000번째까지 병합완료
# tokens 283000번째까지 병합완료
# tokens 284000번째까지 병합완료
# tokens 285000번째까지 병합완료
# tokens 286000번째까지 병합완료
# tokens 287000번째까지 병합완료
# tokens 288000번째까지 병합완료
# tokens 289000번째까지 병합완료
# tokens 290000번째까지 병합완료
# tokens 291000번째까지 병합완료
# tokens 292000번째까지 병합완료
# tokens 293000번째까지 병합완료
# tokens 294000번째까지 병합완료
# tokens 295000번째까지 병합완료
# tokens 296000번째까지 병합완료
# tokens 297000번째까지 병합완료
# tokens 298000번째까지 병합완료
# tokens 299000번째까지 병합완료
# tokens 300000번째까지 병합완료
# tokens 301000번째까지 병합완료
# tokens 302000번째까지 병합완료
# tokens 303000번째까지 병합완료
# tokens 304000번째까지 병합완료
# tokens 305000번째까지 병합완료
# tokens 306000번째까지 병합완료
# tokens 307000번째까지 병합완료
# tokens 308000번째까지 병합완료
# tokens 309000번째까지 병합완료
# tokens 310000번째까지 병합완료
# tokens 311000번째까지 병합완료
# tokens 312000번째까지 병합완료
# tokens 313000번째까지 병합완료
# tokens 314000번째까지 병합완료
# tokens 315000번째까지 병합완료
# tokens 316000번째까지 병합완료
# tokens 317000번째까지 병합완료
# tokens 318000번째까지 병합완료
# tokens 319000번째까지 병합완료
# tokens 320000번째까지 병합완료
# tokens 321000번째까지 병합완료
# tokens 322000번째까지 병합완료
# tokens 323000번째까지 병합완료
# tokens 324000번째까지 병합완료
# tokens 325000번째까지 병합완료
# tokens 326000번째까지 병합완료
# tokens 327000번째까지 병합완료
# tokens 328000번째까지 병합완료
# tokens 329000번째까지 병합완료
# tokens 330000번째까지 병합완료
# tokens 331000번째까지 병합완료
# tokens 332000번째까지 병합완료
# tokens 333000번째까지 병합완료
# tokens 334000번째까지 병합완료
# tokens 335000번째까지 병합완료
# tokens 336000번째까지 병합완료
# tokens 337000번째까지 병합완료
# tokens 338000번째까지 병합완료
# tokens 339000번째까지 병합완료
# tokens 340000번째까지 병합완료
# tokens 341000번째까지 병합완료
# tokens 342000번째까지 병합완료
# tokens 343000번째까지 병합완료
# tokens 344000번째까지 병합완료
# tokens 345000번째까지 병합완료
# tokens 346000번째까지 병합완료
# tokens 347000번째까지 병합완료
# tokens 348000번째까지 병합완료
# tokens 349000번째까지 병합완료
# tokens 350000번째까지 병합완료
# tokens 351000번째까지 병합완료
# tokens 352000번째까지 병합완료
# tokens 353000번째까지 병합완료
# tokens 354000번째까지 병합완료
# tokens 355000번째까지 병합완료
# tokens 356000번째까지 병합완료
# tokens 357000번째까지 병합완료
# tokens 358000번째까지 병합완료
# tokens 359000번째까지 병합완료
# tokens 360000번째까지 병합완료
# tokens 361000번째까지 병합완료
# tokens 362000번째까지 병합완료
# tokens 363000번째까지 병합완료
# tokens 364000번째까지 병합완료
# tokens 365000번째까지 병합완료
# tokens 366000번째까지 병합완료
# tokens 367000번째까지 병합완료
# tokens 368000번째까지 병합완료
# tokens 369000번째까지 병합완료
# tokens 370000번째까지 병합완료
# tokens 371000번째까지 병합완료
# tokens 372000번째까지 병합완료
# tokens 373000번째까지 병합완료
# tokens 374000번째까지 병합완료
# tokens 375000번째까지 병합완료
# tokens 376000번째까지 병합완료
# tokens 377000번째까지 병합완료
# tokens 378000번째까지 병합완료
# tokens 379000번째까지 병합완료
# tokens 380000번째까지 병합완료
# tokens 381000번째까지 병합완료
# tokens 382000번째까지 병합완료
# tokens 383000번째까지 병합완료
# tokens 384000번째까지 병합완료
# tokens 385000번째까지 병합완료
# tokens 386000번째까지 병합완료
# tokens 387000번째까지 병합완료
# tokens 388000번째까지 병합완료
# tokens 389000번째까지 병합완료
# tokens 390000번째까지 병합완료
# tokens 391000번째까지 병합완료
# tokens 392000번째까지 병합완료
# tokens 393000번째까지 병합완료
# tokens 394000번째까지 병합완료
# tokens 395000번째까지 병합완료
# tokens 396000번째까지 병합완료
# tokens 397000번째까지 병합완료
# tokens 398000번째까지 병합완료
# tokens 399000번째까지 병합완료
# tokens 400000번째까지 병합완료
# tokens 401000번째까지 병합완료
# tokens 402000번째까지 병합완료
# tokens 403000번째까지 병합완료
# tokens 404000번째까지 병합완료
# tokens 405000번째까지 병합완료
# tokens 406000번째까지 병합완료
# tokens 407000번째까지 병합완료
# tokens 408000번째까지 병합완료
# tokens 409000번째까지 병합완료
# tokens 410000번째까지 병합완료
# tokens 411000번째까지 병합완료
# tokens 412000번째까지 병합완료
# tokens 413000번째까지 병합완료
# tokens 414000번째까지 병합완료
# tokens 415000번째까지 병합완료
# tokens 416000번째까지 병합완료
# tokens 417000번째까지 병합완료
# tokens 418000번째까지 병합완료
# tokens 419000번째까지 병합완료
# tokens 420000번째까지 병합완료
# tokens 421000번째까지 병합완료
# tokens 422000번째까지 병합완료
# tokens 423000번째까지 병합완료
# tokens 424000번째까지 병합완료
# tokens 425000번째까지 병합완료
# tokens 426000번째까지 병합완료
# tokens 427000번째까지 병합완료
# tokens 428000번째까지 병합완료
# tokens 429000번째까지 병합완료
# tokens 430000번째까지 병합완료
# tokens 431000번째까지 병합완료
# tokens 432000번째까지 병합완료
# tokens 433000번째까지 병합완료
# tokens 434000번째까지 병합완료
# tokens 435000번째까지 병합완료
# tokens 436000번째까지 병합완료
# tokens 437000번째까지 병합완료
# tokens 438000번째까지 병합완료
# tokens 439000번째까지 병합완료
# tokens 440000번째까지 병합완료
# tokens 441000번째까지 병합완료
# tokens 442000번째까지 병합완료
# tokens 443000번째까지 병합완료
# tokens 444000번째까지 병합완료
# tokens 445000번째까지 병합완료
# tokens 446000번째까지 병합완료
# tokens 447000번째까지 병합완료
# tokens 448000번째까지 병합완료
# tokens 449000번째까지 병합완료
# tokens 450000번째까지 병합완료
# tokens 451000번째까지 병합완료
# tokens 452000번째까지 병합완료
# tokens 453000번째까지 병합완료
# tokens 454000번째까지 병합완료
# tokens 455000번째까지 병합완료
# tokens 456000번째까지 병합완료
# tokens 457000번째까지 병합완료
# tokens 458000번째까지 병합완료
# tokens 459000번째까지 병합완료
# tokens 460000번째까지 병합완료
# tokens 461000번째까지 병합완료
# tokens 462000번째까지 병합완료
# tokens 463000번째까지 병합완료
# tokens 464000번째까지 병합완료
# tokens에서 15회 이상 엔그램 추출완료
# ngrams 1000번째까지 병합완료
# ngrams 2000번째까지 병합완료
# ngrams 3000번째까지 병합완료
# ngrams 4000번째까지 병합완료
# ngrams 5000번째까지 병합완료
# ngrams 6000번째까지 병합완료
# ngrams 7000번째까지 병합완료
# ngrams 8000번째까지 병합완료
# ngrams 9000번째까지 병합완료
# ngrams 10000번째까지 병합완료
# ngrams 11000번째까지 병합완료
# ngrams 12000번째까지 병합완료
# ngrams 13000번째까지 병합완료
# ngrams 14000번째까지 병합완료
# ngrams 15000번째까지 병합완료
# ngrams 16000번째까지 병합완료
# ngrams 17000번째까지 병합완료
# ngrams 18000번째까지 병합완료
# ngrams 19000번째까지 병합완료
# ngrams 20000번째까지 병합완료
# ngrams 21000번째까지 병합완료
# ngrams 22000번째까지 병합완료
# ngrams 23000번째까지 병합완료
# ngrams 24000번째까지 병합완료
# ngrams 25000번째까지 병합완료
# ngrams 26000번째까지 병합완료
# ngrams 27000번째까지 병합완료
# ngrams 28000번째까지 병합완료
# ngrams 29000번째까지 병합완료
# ngrams 30000번째까지 병합완료
# ngrams 31000번째까지 병합완료
# ngrams 32000번째까지 병합완료
# ngrams 33000번째까지 병합완료
# ngrams 34000번째까지 병합완료
# ngrams 35000번째까지 병합완료
# ngrams 36000번째까지 병합완료
# ngrams 37000번째까지 병합완료
# ngrams 38000번째까지 병합완료
# ngrams 39000번째까지 병합완료
# ngrams 40000번째까지 병합완료
# ngrams 41000번째까지 병합완료
# ngrams 42000번째까지 병합완료
# ngrams 43000번째까지 병합완료
# ngrams 44000번째까지 병합완료
# ngrams 45000번째까지 병합완료
# ngrams 46000번째까지 병합완료
# ngrams 47000번째까지 병합완료
# ngrams 48000번째까지 병합완료
# ngrams 49000번째까지 병합완료
# ngrams 50000번째까지 병합완료
# ngrams 51000번째까지 병합완료
# ngrams 52000번째까지 병합완료
# ngrams 53000번째까지 병합완료
# ngrams 54000번째까지 병합완료
# ngrams 55000번째까지 병합완료
# ngrams 56000번째까지 병합완료
# ngrams 57000번째까지 병합완료
# ngrams 58000번째까지 병합완료
# ngrams 59000번째까지 병합완료
# ngrams 60000번째까지 병합완료
# ngrams 61000번째까지 병합완료
# ngrams 62000번째까지 병합완료
# ngrams 63000번째까지 병합완료
# ngrams 64000번째까지 병합완료
# ngrams 65000번째까지 병합완료
# ngrams 66000번째까지 병합완료
# ngrams 67000번째까지 병합완료
# ngrams 68000번째까지 병합완료
# ngrams 69000번째까지 병합완료
# ngrams 70000번째까지 병합완료
# ngrams 71000번째까지 병합완료
# ngrams 72000번째까지 병합완료
# ngrams 73000번째까지 병합완료
# ngrams 74000번째까지 병합완료
# ngrams 75000번째까지 병합완료
# ngrams 76000번째까지 병합완료
# ngrams 77000번째까지 병합완료
# ngrams 78000번째까지 병합완료
# ngrams 79000번째까지 병합완료
# ngrams 80000번째까지 병합완료
# ngrams 81000번째까지 병합완료
# ngrams 82000번째까지 병합완료
# ngrams 83000번째까지 병합완료
# ngrams 84000번째까지 병합완료
# ngrams 85000번째까지 병합완료
# ngrams 86000번째까지 병합완료
# ngrams 87000번째까지 병합완료
# ngrams 88000번째까지 병합완료
# ngrams 89000번째까지 병합완료
# ngrams 90000번째까지 병합완료
# ngrams 91000번째까지 병합완료
# ngrams 92000번째까지 병합완료
# ngrams 93000번째까지 병합완료
# ngrams 94000번째까지 병합완료
# ngrams 95000번째까지 병합완료
# ngrams 96000번째까지 병합완료
# ngrams 97000번째까지 병합완료
# ngrams 98000번째까지 병합완료
# ngrams 99000번째까지 병합완료
# ngrams 100000번째까지 병합완료
# ngrams 101000번째까지 병합완료
# ngrams 102000번째까지 병합완료
# ngrams 103000번째까지 병합완료
# ngrams 104000번째까지 병합완료
# ngrams 105000번째까지 병합완료
# ngrams 106000번째까지 병합완료
# ngrams 107000번째까지 병합완료
# ngrams 108000번째까지 병합완료
# ngrams 109000번째까지 병합완료
# ngrams 110000번째까지 병합완료
# ngrams 111000번째까지 병합완료
# ngrams 112000번째까지 병합완료
# ngrams 113000번째까지 병합완료
# ngrams 114000번째까지 병합완료
# ngrams 115000번째까지 병합완료
# ngrams 116000번째까지 병합완료
# ngrams 117000번째까지 병합완료
# ngrams 118000번째까지 병합완료
# ngrams 119000번째까지 병합완료
# ngrams 120000번째까지 병합완료
# ngrams 121000번째까지 병합완료
# ngrams 122000번째까지 병합완료
# ngrams 123000번째까지 병합완료
# ngrams 124000번째까지 병합완료
# ngrams 125000번째까지 병합완료
# ngrams 126000번째까지 병합완료
# ngrams 127000번째까지 병합완료
# ngrams 128000번째까지 병합완료
# ngrams 129000번째까지 병합완료
# ngrams 130000번째까지 병합완료
# ngrams 131000번째까지 병합완료
# ngrams 132000번째까지 병합완료
# ngrams 133000번째까지 병합완료
# ngrams 134000번째까지 병합완료
# ngrams 135000번째까지 병합완료
# ngrams 136000번째까지 병합완료
# ngrams 137000번째까지 병합완료
# ngrams 138000번째까지 병합완료
# ngrams 139000번째까지 병합완료
# ngrams 140000번째까지 병합완료
# ngrams 141000번째까지 병합완료
# ngrams 142000번째까지 병합완료
# ngrams 143000번째까지 병합완료
# ngrams 144000번째까지 병합완료
# ngrams 145000번째까지 병합완료
# ngrams 146000번째까지 병합완료
# ngrams 147000번째까지 병합완료
# ngrams 148000번째까지 병합완료
# ngrams 149000번째까지 병합완료
# ngrams 150000번째까지 병합완료
# ngrams 151000번째까지 병합완료
# ngrams 152000번째까지 병합완료
# ngrams 153000번째까지 병합완료
# ngrams 154000번째까지 병합완료
# ngrams 155000번째까지 병합완료
# ngrams 156000번째까지 병합완료
# ngrams 157000번째까지 병합완료
# ngrams 158000번째까지 병합완료
# ngrams 159000번째까지 병합완료
# ngrams 160000번째까지 병합완료
# ngrams 161000번째까지 병합완료
# ngrams 162000번째까지 병합완료
# ngrams 163000번째까지 병합완료
# ngrams 164000번째까지 병합완료
# ngrams 165000번째까지 병합완료
# ngrams 166000번째까지 병합완료
# ngrams 167000번째까지 병합완료
# ngrams 168000번째까지 병합완료
# ngrams 169000번째까지 병합완료
# ngrams 170000번째까지 병합완료
# ngrams 171000번째까지 병합완료
# ngrams 172000번째까지 병합완료
# ngrams 173000번째까지 병합완료
# ngrams 174000번째까지 병합완료
# ngrams 175000번째까지 병합완료
# ngrams 176000번째까지 병합완료
# ngrams 177000번째까지 병합완료
# ngrams 178000번째까지 병합완료
# ngrams 179000번째까지 병합완료
# ngrams 180000번째까지 병합완료
# ngrams 181000번째까지 병합완료
# ngrams 182000번째까지 병합완료
# ngrams 183000번째까지 병합완료
# ngrams 184000번째까지 병합완료
# ngrams 185000번째까지 병합완료
# ngrams 186000번째까지 병합완료
# ngrams 187000번째까지 병합완료
# ngrams 188000번째까지 병합완료
# ngrams 189000번째까지 병합완료
# ngrams 190000번째까지 병합완료
# ngrams 191000번째까지 병합완료
# ngrams 192000번째까지 병합완료
# ngrams 193000번째까지 병합완료
# ngrams 194000번째까지 병합완료
# ngrams 195000번째까지 병합완료
# ngrams 196000번째까지 병합완료
# ngrams 197000번째까지 병합완료
# ngrams 198000번째까지 병합완료
# ngrams 199000번째까지 병합완료
# ngrams 200000번째까지 병합완료
# ngrams 201000번째까지 병합완료
# ngrams 202000번째까지 병합완료
# ngrams 203000번째까지 병합완료
# ngrams 204000번째까지 병합완료
# ngrams 205000번째까지 병합완료
# ngrams 206000번째까지 병합완료
# ngrams 207000번째까지 병합완료
# ngrams 208000번째까지 병합완료
# ngrams 209000번째까지 병합완료
# ngrams 210000번째까지 병합완료
# ngrams 211000번째까지 병합완료
# ngrams 212000번째까지 병합완료
# ngrams 213000번째까지 병합완료
# ngrams 214000번째까지 병합완료
# ngrams 215000번째까지 병합완료
# ngrams 216000번째까지 병합완료
# ngrams 217000번째까지 병합완료
# ngrams 218000번째까지 병합완료
# ngrams 219000번째까지 병합완료
# ngrams 220000번째까지 병합완료
# ngrams 221000번째까지 병합완료
# ngrams 222000번째까지 병합완료
# ngrams 223000번째까지 병합완료
# ngrams 224000번째까지 병합완료
# ngrams 225000번째까지 병합완료
# ngrams 226000번째까지 병합완료
# ngrams 227000번째까지 병합완료
# ngrams 228000번째까지 병합완료
# ngrams 229000번째까지 병합완료
# ngrams 230000번째까지 병합완료
# ngrams 231000번째까지 병합완료
# ngrams 232000번째까지 병합완료
# ngrams 233000번째까지 병합완료
# ngrams 234000번째까지 병합완료
# ngrams 235000번째까지 병합완료
# ngrams 236000번째까지 병합완료
# ngrams 237000번째까지 병합완료
# ngrams 238000번째까지 병합완료
# ngrams 239000번째까지 병합완료
# ngrams 240000번째까지 병합완료
# ngrams 241000번째까지 병합완료
# ngrams 242000번째까지 병합완료
# ngrams 243000번째까지 병합완료
# ngrams 244000번째까지 병합완료
# ngrams 245000번째까지 병합완료
# ngrams 246000번째까지 병합완료
# ngrams 247000번째까지 병합완료
# ngrams 248000번째까지 병합완료
# ngrams 249000번째까지 병합완료
# ngrams 250000번째까지 병합완료
# ngrams 251000번째까지 병합완료
# ngrams 252000번째까지 병합완료
# ngrams 253000번째까지 병합완료
# ngrams 254000번째까지 병합완료
# ngrams 255000번째까지 병합완료
# ngrams 256000번째까지 병합완료
# ngrams 257000번째까지 병합완료
# ngrams 258000번째까지 병합완료
# ngrams 259000번째까지 병합완료
# ngrams 260000번째까지 병합완료
# ngrams 261000번째까지 병합완료
# ngrams 262000번째까지 병합완료
# ngrams 263000번째까지 병합완료
# ngrams 264000번째까지 병합완료
# ngrams 265000번째까지 병합완료
# ngrams 266000번째까지 병합완료
# ngrams 267000번째까지 병합완료
# ngrams 268000번째까지 병합완료
# ngrams 269000번째까지 병합완료
# ngrams 270000번째까지 병합완료
# ngrams 271000번째까지 병합완료
# ngrams 272000번째까지 병합완료
# ngrams 273000번째까지 병합완료
# ngrams 274000번째까지 병합완료
# ngrams 275000번째까지 병합완료
# ngrams 276000번째까지 병합완료
# ngrams 277000번째까지 병합완료
# ngrams 278000번째까지 병합완료
# ngrams 279000번째까지 병합완료
# ngrams 280000번째까지 병합완료
# ngrams 281000번째까지 병합완료
# ngrams 282000번째까지 병합완료
# ngrams 283000번째까지 병합완료
# ngrams 284000번째까지 병합완료
# ngrams 285000번째까지 병합완료
# ngrams 286000번째까지 병합완료
# ngrams 287000번째까지 병합완료
# ngrams 288000번째까지 병합완료
# ngrams 289000번째까지 병합완료
# ngrams 290000번째까지 병합완료
# ngrams 291000번째까지 병합완료
# ngrams 292000번째까지 병합완료
# ngrams 293000번째까지 병합완료
# ngrams 294000번째까지 병합완료
# ngrams 295000번째까지 병합완료
# ngrams 296000번째까지 병합완료
# ngrams 297000번째까지 병합완료
# ngrams 298000번째까지 병합완료
# ngrams 299000번째까지 병합완료
# ngrams 300000번째까지 병합완료
# ngrams 301000번째까지 병합완료
# ngrams 302000번째까지 병합완료
# ngrams 303000번째까지 병합완료
# ngrams 304000번째까지 병합완료
# ngrams 305000번째까지 병합완료
# ngrams 306000번째까지 병합완료
# ngrams 307000번째까지 병합완료
# ngrams 308000번째까지 병합완료
# ngrams 309000번째까지 병합완료
# ngrams 310000번째까지 병합완료
# ngrams 311000번째까지 병합완료
# ngrams 312000번째까지 병합완료
# ngrams 313000번째까지 병합완료
# ngrams 314000번째까지 병합완료
# ngrams 315000번째까지 병합완료
# ngrams 316000번째까지 병합완료
# ngrams 317000번째까지 병합완료
# ngrams 318000번째까지 병합완료
# ngrams 319000번째까지 병합완료
# ngrams 320000번째까지 병합완료
# ngrams 321000번째까지 병합완료
# ngrams 322000번째까지 병합완료
# ngrams 323000번째까지 병합완료
# ngrams 324000번째까지 병합완료
# ngrams 325000번째까지 병합완료
# ngrams 326000번째까지 병합완료
# ngrams 327000번째까지 병합완료
# ngrams 328000번째까지 병합완료
# ngrams 329000번째까지 병합완료
# ngrams 330000번째까지 병합완료
# ngrams 331000번째까지 병합완료
# ngrams 332000번째까지 병합완료
# ngrams 333000번째까지 병합완료
# ngrams 334000번째까지 병합완료
# ngrams 335000번째까지 병합완료
# ngrams 336000번째까지 병합완료
# ngrams 337000번째까지 병합완료
# ngrams 338000번째까지 병합완료
# ngrams 339000번째까지 병합완료
# ngrams 340000번째까지 병합완료
# ngrams 341000번째까지 병합완료
# ngrams 342000번째까지 병합완료
# ngrams 343000번째까지 병합완료
# ngrams 344000번째까지 병합완료
# ngrams 345000번째까지 병합완료
# ngrams 346000번째까지 병합완료
# ngrams 347000번째까지 병합완료
# ngrams 348000번째까지 병합완료
# ngrams 349000번째까지 병합완료
# ngrams 350000번째까지 병합완료
# ngrams 351000번째까지 병합완료
# ngrams 352000번째까지 병합완료
# ngrams 353000번째까지 병합완료
# ngrams 354000번째까지 병합완료
# ngrams 355000번째까지 병합완료
# ngrams 356000번째까지 병합완료
# ngrams 357000번째까지 병합완료
# ngrams 358000번째까지 병합완료
# ngrams 359000번째까지 병합완료
# ngrams 360000번째까지 병합완료
# ngrams 361000번째까지 병합완료
# ngrams 362000번째까지 병합완료
# ngrams 363000번째까지 병합완료
# ngrams 364000번째까지 병합완료
# ngrams 365000번째까지 병합완료
# ngrams 366000번째까지 병합완료
# ngrams 367000번째까지 병합완료
# ngrams 368000번째까지 병합완료
# ngrams 369000번째까지 병합완료
# ngrams 370000번째까지 병합완료
# ngrams 371000번째까지 병합완료
# ngrams 372000번째까지 병합완료
# ngrams 373000번째까지 병합완료
# ngrams 374000번째까지 병합완료
# ngrams 375000번째까지 병합완료
# ngrams 376000번째까지 병합완료
# ngrams 377000번째까지 병합완료
# ngrams 378000번째까지 병합완료
# ngrams 379000번째까지 병합완료
# ngrams 380000번째까지 병합완료
# ngrams 381000번째까지 병합완료
# ngrams 382000번째까지 병합완료
# ngrams 383000번째까지 병합완료
# ngrams 384000번째까지 병합완료
# ngrams 385000번째까지 병합완료
# ngrams 386000번째까지 병합완료
# ngrams 387000번째까지 병합완료
# ngrams 388000번째까지 병합완료
# ngrams 389000번째까지 병합완료
# ngrams 390000번째까지 병합완료
# ngrams 391000번째까지 병합완료
# ngrams 392000번째까지 병합완료
# ngrams 393000번째까지 병합완료
# ngrams 394000번째까지 병합완료
# ngrams 395000번째까지 병합완료
# ngrams 396000번째까지 병합완료
# ngrams 397000번째까지 병합완료
# ngrams 398000번째까지 병합완료
# ngrams 399000번째까지 병합완료
# ngrams 400000번째까지 병합완료
# ngrams 401000번째까지 병합완료
# ngrams 402000번째까지 병합완료
# ngrams 403000번째까지 병합완료
# ngrams 404000번째까지 병합완료
# ngrams 405000번째까지 병합완료
# ngrams 406000번째까지 병합완료
# ngrams 407000번째까지 병합완료
# ngrams 408000번째까지 병합완료
# ngrams 409000번째까지 병합완료
# ngrams 410000번째까지 병합완료
# ngrams 411000번째까지 병합완료
# ngrams 412000번째까지 병합완료
# ngrams 413000번째까지 병합완료
# ngrams 414000번째까지 병합완료
# ngrams 415000번째까지 병합완료
# ngrams 416000번째까지 병합완료
# ngrams 417000번째까지 병합완료
# ngrams 418000번째까지 병합완료
# ngrams 419000번째까지 병합완료
# ngrams 420000번째까지 병합완료
# ngrams 421000번째까지 병합완료
# ngrams 422000번째까지 병합완료
# ngrams 423000번째까지 병합완료
# ngrams 424000번째까지 병합완료
# ngrams 425000번째까지 병합완료
# ngrams 426000번째까지 병합완료
# ngrams 427000번째까지 병합완료
# ngrams 428000번째까지 병합완료
# ngrams 429000번째까지 병합완료
# ngrams 430000번째까지 병합완료
# ngrams 431000번째까지 병합완료
# ngrams 432000번째까지 병합완료
# ngrams 433000번째까지 병합완료
# ngrams 434000번째까지 병합완료
# ngrams 435000번째까지 병합완료
# ngrams 436000번째까지 병합완료
# ngrams 437000번째까지 병합완료
# ngrams 438000번째까지 병합완료
# ngrams 439000번째까지 병합완료
# ngrams 440000번째까지 병합완료
# ngrams 441000번째까지 병합완료
# ngrams 442000번째까지 병합완료
# ngrams 443000번째까지 병합완료
# ngrams 444000번째까지 병합완료
# ngrams 445000번째까지 병합완료
# ngrams 446000번째까지 병합완료
# ngrams 447000번째까지 병합완료
# ngrams 448000번째까지 병합완료
# ngrams 449000번째까지 병합완료
# ngrams 450000번째까지 병합완료
# ngrams 451000번째까지 병합완료
# ngrams 452000번째까지 병합완료
# ngrams 453000번째까지 병합완료
# ngrams 454000번째까지 병합완료
# ngrams 455000번째까지 병합완료
# ngrams 456000번째까지 병합완료
# ngrams 457000번째까지 병합완료
# ngrams 458000번째까지 병합완료
# ngrams 459000번째까지 병합완료
# ngrams 460000번째까지 병합완료
# ngrams 461000번째까지 병합완료
# ngrams 462000번째까지 병합완료
# ngrams 463000번째까지 병합완료
# ngrams 464000번째까지 병합완료
# ngrams에서 15회 이상 엔그램 추출완료
# 52640

# %%
def polarScore(df, lst):
    posDf = df[df['label']=='pos']
    negDf = df[df['label']=='neg']
    print('라벨에 따른 의사록 데이터프레임 분류완료')
    
    allPosTokens=[]
    allNegTokens=[]
    allPosNgrams=[]
    allNegNgrams=[]
    
    for item in posDf['tokens']:
        li = eval(item)
        allPosTokens.extend(li)
    print('pos라벨 tokens병합완료')
    
    for item in posDf['ngrams']:
        li = eval(item)
        allPosNgrams.extend(li)
    print('pos라벨 ngrams병합완료')
    
    allPos = allPosTokens+allPosNgrams

    for item in negDf['tokens']:
        li = eval(item)
        allNegTokens.extend(li)
    print('neg라벨 tokens병합완료')
        
    for item in negDf['ngrams']:
        li = eval(item)
        allNegNgrams.extend(li)
    print('neg라벨 ngrams병합완료')
    
    allNeg = allNegTokens+allNegNgrams
    
    pos_cnt = len(allPos)
    neg_cnt = len(allNeg)
    
    # polarity score 산출
    pos_list=[]
    neg_list=[]
    
    allPos_valuecounts = pd.Series(allPos).value_counts()
    allNeg_valuecounts = pd.Series(allNeg).value_counts()
    
    print('중간준비 완료')
    
    i=0
    for ngram in lst:
        
        if ngram not in allNeg_valuecounts.index and ngram not in allPos_valuecounts.index:
            score = 1
        elif ngram not in allNeg_valuecounts.index:
            score = (allPos_valuecounts[ngram]/pos_cnt) / (1/neg_cnt)
        elif ngram not in allPos_valuecounts.index:
            score = 0
        else:
            score = (allPos_valuecounts[ngram]/pos_cnt) / (allNeg_valuecounts[ngram]/neg_cnt)
            
        if score >= 1.3:
            pos_list.append(ngram)
        elif score <= (1/1.3):
            neg_list.append(ngram)
            
        i+=1
        if i%1000==0:
            print('{}번째 진행완료 / 총 {}개'.format(i, len(lst)))
            
    return pos_list, neg_list

# %%
pos_list, neg_list = polarScore(bond_doctor, ngrams_over15)
pos_list[:10], neg_list[:10]
# Out:
# 라벨에 따른 의사록 데이터프레임 분류완료
# pos라벨 tokens병합완료
# pos라벨 ngrams병합완료
# neg라벨 tokens병합완료
# neg라벨 ngrams병합완료
# 중간준비 완료
# 1000번째 진행완료 / 총 52640개
# 2000번째 진행완료 / 총 52640개
# 3000번째 진행완료 / 총 52640개
# 4000번째 진행완료 / 총 52640개
# 5000번째 진행완료 / 총 52640개
# 6000번째 진행완료 / 총 52640개
# 7000번째 진행완료 / 총 52640개
# 8000번째 진행완료 / 총 52640개
# 9000번째 진행완료 / 총 52640개
# 10000번째 진행완료 / 총 52640개
# 11000번째 진행완료 / 총 52640개
# 12000번째 진행완료 / 총 52640개
# 13000번째 진행완료 / 총 52640개
# 14000번째 진행완료 / 총 52640개
# 15000번째 진행완료 / 총 52640개
# 16000번째 진행완료 / 총 52640개
# 17000번째 진행완료 / 총 52640개
# 18000번째 진행완료 / 총 52640개
# 19000번째 진행완료 / 총 52640개
# 20000번째 진행완료 / 총 52640개
# 21000번째 진행완료 / 총 52640개
# 22000번째 진행완료 / 총 52640개
# 23000번째 진행완료 / 총 52640개
# 24000번째 진행완료 / 총 52640개
# 25000번째 진행완료 / 총 52640개
# 26000번째 진행완료 / 총 52640개
# 27000번째 진행완료 / 총 52640개
# 28000번째 진행완료 / 총 52640개
# 29000번째 진행완료 / 총 52640개
# 30000번째 진행완료 / 총 52640개
# 31000번째 진행완료 / 총 52640개
# 32000번째 진행완료 / 총 52640개
# 33000번째 진행완료 / 총 52640개
# 34000번째 진행완료 / 총 52640개
# 35000번째 진행완료 / 총 52640개
# 36000번째 진행완료 / 총 52640개
# 37000번째 진행완료 / 총 52640개
# 38000번째 진행완료 / 총 52640개
# 39000번째 진행완료 / 총 52640개
# 40000번째 진행완료 / 총 52640개
# 41000번째 진행완료 / 총 52640개
# 42000번째 진행완료 / 총 52640개
# 43000번째 진행완료 / 총 52640개
# 44000번째 진행완료 / 총 52640개
# 45000번째 진행완료 / 총 52640개
# 46000번째 진행완료 / 총 52640개
# 47000번째 진행완료 / 총 52640개
# 48000번째 진행완료 / 총 52640개
# 49000번째 진행완료 / 총 52640개
# 50000번째 진행완료 / 총 52640개
# 51000번째 진행완료 / 총 52640개
# 52000번째 진행완료 / 총 52640개
# (['빠르/VA',
#   '뉴스/NNG',
#   '위안/NNG',
#   '기사/NNG',
#   '긴축/NNG',
#   '콜/NNG',
#   '절상/NNG',
#   '무료/NNG',
#   '프리미엄/NNG',
#   '추천/NNG'],
#  ['인하/NNG',
#   '침체/NNG',
#   '브렉시트/NNG',
#   '금융위기/NNG',
#   '구조조정/NNG',
#   '클릭/NNG',
#   '부양/NNG',
#   '안전자산/NNG',
#   '부양책/NNG',
#   '은행채/NNG'])

# %%
pos_df = pd.DataFrame({'pos':pos_list})
neg_df = pd.DataFrame({'neg':neg_list})

# %%
pos_df.to_csv('pos_df.csv',encoding = 'cp949')
neg_df.to_csv('neg_df.csv',encoding = 'cp949')

# %%
len(pos_list),len(neg_list)
# Out:
# (14088, 16117)

# %%
def get_stTone(df, pos_tup, neg_tup):
    df['SentenceTone']=None
    for idx in range(len(df)):
        pos_cnt = 0
        neg_cnt = 0
        li = eval((df['tokens']+df['ngrams'])[idx].replace('][',''))
        for item in li:
            if item in pos_tup:
                pos_cnt += 1
            elif item in neg_tup:
                neg_cnt += 1
        if (pos_cnt+neg_cnt) == 0:
            stTone = 0
        else:
            stTone = (pos_cnt-neg_cnt) / (pos_cnt+neg_cnt)
        df['SentenceTone'][idx] = stTone
    if idx%30==0:
        print(idx)
    return df

# %%
new_doctorrock = get_stTone(doctorrock_label, pos_list, neg_list)
new_doctorrock.head()
# Out:
#          date                                             tokens  \
# 0  2005-06-09  ['경제/NNG', '경제/NNG', '비해/VV', '더/MAG', '낫/VV',...
# 1  2005-06-09  ['환율/NNG', '장기/NNG', '각국/NNG', '기초/NNG', '경제/N...
# 2  2005-06-09  ['유로존/NNG', '경제/NNG', '성장/NNG', '실적/NNG', '예상/...
# 3  2005-06-09  ['금리/NNG', '수준/NNG', '유지/NNG', '되/XSV', '금리/NN...
# 4  2005-06-09  ['실물/NNG', '경제/NNG', '시차/NNG', '두/VV', '밀접/NNG...
#
#                                               ngrams label SentenceTone
# 0  ['엔달러/NNG;환율/NNG;상승/NNG', '기대/NNG;원화/NNG;절상/NN...   neg     0.714286
# 1  ['원엔/NNG;환율/NNG;하락/NNG', '일시적/VAX;외부충격/NNG', '...   neg           -1
# 2  ['유로존/NNG;경제/NNG;성장/NNG', '실적/NNG;예상/NNG;저조/NN...   neg           -1
# 3  ['자본/NNG;유출/NNG;확대/NNG', '금리/NNG;상승/NNG', '원화/...   neg            1
# 4                                                 []   neg           -1

# %%
def get_drTone(df):
    dr_tone_lst = []
    unq_date = sorted((list(set(df['date']))))
    for date in unq_date:
        target = df[df['date']==date]
        hawk_cnt = len(target[target['SentenceTone'] > 0])
        dove_cnt = len(target[target['SentenceTone'] < 0])
        dr_tone = (hawk_cnt - dove_cnt) / (hawk_cnt + dove_cnt)
        dr_tone_lst.append([date, dr_tone])
    return pd.DataFrame(dr_tone_lst, columns=['의사록날짜','톤 스코어'])

# %%
result = get_drTone(new_doctorrock)
result.head()
# Out:
#         의사록날짜     톤 스코어
# 0  2005-06-09 -0.500000
# 1  2005-07-07 -0.500000
# 2  2005-08-11  0.454545
# 3  2005-09-08 -0.500000
# 4  2005-10-11  0.000000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(12,10))
plt.plot(result['톤 스코어'])
plt.ylim(-2,2)
# Out:
# (-2, 2)

# %%
sr = pd.read_json('기준금리.json')
sorted_sr = sr.sort_values(by=['date'], axis=0)
sorted_sr.index = range(len(sorted_sr))
sorted_sr['date'] = pd.to_datetime(sorted_sr['date'],format = '%Y%m%d')
new_df = pd.DataFrame({'date' : pd.date_range('20041111','20171231')})
base_rate = new_df.merge(sorted_sr, on = 'date', how = 'left').fillna(method='ffill')[51:]
base_rate.index = range(len(base_rate))
base_rate.head()
# Out:
#         date  baseRate
# 0 2005-01-01      3.25
# 1 2005-01-02      3.25
# 2 2005-01-03      3.25
# 3 2005-01-04      3.25
# 4 2005-01-05      3.25

# %%
new_df = pd.DataFrame({'의사록날짜' : pd.date_range('20050101','20171231')})
result['의사록날짜'] = pd.to_datetime(result['의사록날짜'])
result2 = new_df.merge(result, on = '의사록날짜', how = 'left').fillna(method='bfill')
result2.columns = ['date','톤 스코어']
result2.head()
# Out:
#         date  톤 스코어
# 0 2005-01-01   -0.5
# 1 2005-01-02   -0.5
# 2 2005-01-03   -0.5
# 3 2005-01-04   -0.5
# 4 2005-01-05   -0.5

# %%
plt.figure(figsize=(15,10))
plt.plot(result2['톤 스코어']/result2['톤 스코어'][0]*(-100))
plt.plot(base_rate['baseRate']/base_rate['baseRate'][0]*100-130)

# %% [markdown]
# # 채권보고서, 의사록만 이용한 부분 ->

# %%
result = get_drTone(new_doctorrock)
result.head()
# Out:
#         의사록날짜     톤 스코어
# 0  2005-06-09 -0.666667
# 1  2005-07-07 -0.142857
# 2  2005-08-11  0.375000
# 3  2005-09-08 -0.384615
# 4  2005-10-11 -0.111111

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=(12,10))
plt.plot(result['톤 스코어'])
plt.ylim(-2,2)
# Out:
# (-2, 2)

# %% [markdown]
# ## 기준금리 데이터프레임화

# %% [markdown]
# ### 기준금리 합치기

# %%
sr = pd.read_json('기준금리.json')
sorted_sr = sr.sort_values(by=['date'], axis=0)
sorted_sr.index = range(len(sorted_sr))
sorted_sr['date'] = pd.to_datetime(sorted_sr['date'],format = '%Y%m%d')
new_df = pd.DataFrame({'date' : pd.date_range('20041111','20171231')})
base_rate = new_df.merge(sorted_sr, on = 'date', how = 'left').fillna(method='ffill')[51:]
base_rate.index = range(len(base_rate))
base_rate.head()
# Out:
#         date  baseRate
# 0 2005-01-01      3.25
# 1 2005-01-02      3.25
# 2 2005-01-03      3.25
# 3 2005-01-04      3.25
# 4 2005-01-05      3.25

# %%
plt.plot(base_rate['baseRate'])
plt.ylim(-3,9)
# Out:
# (-3, 9)

# %% [markdown]
# ### 의사록 fillna(bfill)

# %%
new_df = pd.DataFrame({'의사록날짜' : pd.date_range('20050101','20171231')})
result['의사록날짜'] = pd.to_datetime(result['의사록날짜'])
result2 = new_df.merge(result, on = '의사록날짜', how = 'left').fillna(method='bfill')
result2.columns = ['date','톤 스코어']
result2.head()
# Out:
#         date     톤 스코어
# 0 2005-01-01 -0.666667
# 1 2005-01-02 -0.666667
# 2 2005-01-03 -0.666667
# 3 2005-01-04 -0.666667
# 4 2005-01-05 -0.666667

# %%
plt.figure(figsize=(15,10))
plt.plot(result2['톤 스코어']/result2['톤 스코어'][0]*(-100))
plt.plot(base_rate['baseRate']/base_rate['baseRate'][0]*100-130)
# plt.legend(['톤','기준금리'])
# plt.ylim(-2,2)

# %% [markdown]
# # <- 채권보고서, 의사록만 사용한 부분 끝

# %%
df = pd.DataFrame({'기준금리':base_rate['baseRate'],
             '의사록톤':result2['톤 스코어']})

# %%
df.corr('pearson')
# Out:
#           기준금리      의사록톤
# 기준금리  1.000000  0.361642
# 의사록톤  0.361642  1.000000

# %%
result.columns = ['date','톤스코어']
result.head()
# Out:
#         date      톤스코어
# 0 2005-06-09 -0.500000
# 1 2005-07-07 -0.500000
# 2 2005-08-11  0.454545
# 3 2005-09-08 -0.500000
# 4 2005-10-11  0.000000

# %%
base_rate.head()
# Out:
#         date  baseRate
# 0 2005-01-01      3.25
# 1 2005-01-02      3.25
# 2 2005-01-03      3.25
# 3 2005-01-04      3.25
# 4 2005-01-05      3.25

# %%
df = result.merge(base_rate, on='date', how='left')
df.head()
# Out:
#         date      톤스코어  baseRate
# 0 2005-06-09 -0.500000      3.25
# 1 2005-07-07 -0.500000      3.25
# 2 2005-08-11  0.454545      3.25
# 3 2005-09-08 -0.500000      3.25
# 4 2005-10-11  0.000000      3.50

# %%
df.corr('pearson')
# Out:
#               톤스코어  baseRate
# 톤스코어      1.000000  0.415041
# baseRate  0.415041  1.000000
